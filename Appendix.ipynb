# %% [markdown]
# # Appendix: Install PyTorch and Enable GPU Training Locally and in Colab

# %% [markdown]
# This appendix covers:
#
# * How to install Anaconda on your computer based on your operating system
# * Creating a Python virtual environment for projects in this book
# * Installing Jupyter Notebook in the virtual environment
# * Installing PyTorch with a CUDA-enabled GPU
# * Accelerating training with GPUs in Google Colab for free
#
#
# My preferred way of installing Python and managing libraries and packages on your computer is through Anaconda, an open-source Python distribution, package manager, and environment management tool. Anaconda is user-friendly and can help you effortlessly install numerous libraries and packages, which could be a pain to install otherwise. Anaconda allows users to install packages through both 'conda install' and 'pip install,' broadening the spectrum of available resources.
#
# I will also walk you through the steps in creating a dedicated Python virtual environment for all the projects in this book. This segregation ensures that the libraries and packages used in this book remain isolated from any libraries utilized in other, unrelated projects, thus eliminating any potential interference.
#
# We will use Jupyter Notebook as our integrated development environment (IDE). I will guide you through the installation of Jupyter Notebook in the Python virtual environment you just created. You’ll also learn to install PyTorch, Torchvision, and Torchaudio, if your computer is equipped with a Compute Unified Device Architecture (CUDA)-enabled GPU.
#
# In case you don’t have a CUDA-enabled GPU on your computer, you are encouraged to train models in the Google Colab for free. Because many models in this book contain hundreds of millions of parameters, running these models may become impractically slow without GPU acceleration. I’ll discuss at the end of this appendix on how to train models with a GPU in Google Colab.

# %% [markdown]
# # 1. Install Python and Set Up a Virtual Environment
# In this section, I’ll guide you through the process of installing Anaconda on your computer based on your operating system. After that, you’ll create a Python virtual environment for all projects in this book. Finally, you’ll install Jupyter Notebook as your IDE to run Python programs in this book.

# %% [markdown]
# ## 1.1. Install Anaconda
# To install Python through the Anaconda distribution, follow the following steps.
# First, go to the official Anaconda website at https://www.anaconda.com/download/success and scroll to the bottom of the webpage. Locate and download the most recent Python 3 version tailored to your specific operating system (Windows, macOS, or Linux).
# If you are using Windows, download the latest Python 3 graphical installer from the above link. Click on the installer and follow the instructions to install. For macOS users, the latest Python 3 graphical installer for Mac is recommended, although a command line installer option is also available. The installation process for Linux is more complex than for other operating systems, as there is no graphical installer. Begin by identifying the appropriate package. Click to download the latest installer bash script. The installer bash script is typically saved to your computer's "Downloads" folder by default. Install Anaconda by executing the bash script within a terminal. Upon completing the installation, activate it by running the following command:
#
# `
# source ~/.bashrc
# `
#
# To access Anaconda Navigator, enter the following command in a terminal:
#
# `
# anaconda-navigator
# `
#
# If you can successfully launch the Anaconda Navigator on your computer, your installation of Anaconda is complete.

# %% [markdown]
# ## 1.2. Create A Virtual Environment
# It's highly recommended that you create a separate virtual environment for this book. Let’s name the virtual environment dgai. Execute the following command in the Anaconda prompt (Windows) or a terminal (Mac and Linux):
#
# `conda create -n txt2img`
#
# After pressing the ENTER key on your keyboard, follow the instructions on the screen and press y when the prompt asks you y/n. To activate the virtual environment, run the following command in the same Anaconda prompt (Windows) or terminal (Mac and Linux):
#
# `conda activate txt2img`
#
# The virtual environment isolates the Python packages and libraries that you use for this book from other packages and libraries that you use for other purposes. This prevents any undesired interference.

# %% [markdown]
# ## 1.3. Set Up Jupyter Notebook in the Virtual Environment
# Now, let’s install Jupyter Notebook in the newly created virtual environment on your computer.
# First, activate the virtual environment by running the following line of code in the Anaconda prompt (in Windows) or a terminal (in Mac or Linux):
#
# `conda activate txt2img`
#
# To install Jupyter Notebook in the virtual environment, run the command:
#
# `conda install notebook`
#
# Follow the instructions all the way through to install the app.
# To launch Jupyter Notebook, execute the following command in the same terminal with the virtual environment activated:
#
# `jupyter notebook`
#
# The Jupyter Notebook app will open in your default browser.

# %% [markdown]
# # 2. Install PyTorch

# %% [markdown]
# CUDA is only available on Windows or Linux, not on Mac. To find out if your computer is equipped with a CUDA-enabled GPU, open the Windows PowerShell (in Windows) or a terminal (in Linux), issue the following command:
#
# `nvidia-smi`
#
# If your computer has a CUDA-enabled GPU, you should see an output similar to figure Appendix.1. Further, make a note of the CUDA version as shown at the top right corner of the figure because you’ll need this piece of information later when you install PyTorch. Figure Appendix.1 shows that the CUDA version is 12.6 on my computer. The version may be different on your computer.

# %% [markdown]
# ![smi.png](attachment:smi.png)
#
# Figure Appendix.1 Checking if your computer has a CUDA-enabled GPU.

# %% [markdown]
# ## 2.1. Install PyTorch with GPUs

# %% [markdown]
# To install PyTorch with CUDA, first find out the CUDA version of your GPU, as shown at the top right corner of figure Appendix.1. My CUDA version is 12.6 so I’ll use it as an example in the installation below.
#
# If you go to the PyTorch website here, https://pytorch.org/get-started/locally/, you’ll see an interactive interface as shown in figure Appendix.2.

# %% [markdown]
# ![figA.2%28resolution300%29.png](attachment:figA.2%28resolution300%29.png)

# %% [markdown]
# Figure Appendix.2 The interactive interface on how to install PyTorch
#
# Once there, choose your operating system, select Pip as the Package, Python as the Language, and the closest Computer Platform. The command you need to run will be shown at the bottom panel. For example, I am using the Windows operating system, and I have CUDA 12.6 on my GPU. Therefore, the command for me is shown at the bottom panel of figure Appendix.2.
#
# Once you know what command to run to install PyTorch with CUDA, activate the virtual environment and issue the line of command you have found out in the last step. For me, the command line is:
#
# ```
# pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126
# ```
#
# To make sure you have PyTorch correctly installed, run the following lines of code in a new cell in Jupyter Notebook:

# %%
import torch, torchvision, torchaudio

print(torch.__version__)
print(torchvision.__version__)
print(torchaudio.__version__)
device="cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# 2.6.0+cu126
# 0.21.0+cu126
# 2.6.0+cu126
# cuda

# %% [markdown]
# The output above says *cuda*, indicating that GPU training is available on my computer. If you don't have cuda-enabled GPU on your computer, the output is *cpu*.

# %% [markdown]
# If you have an Apple Mac,
# you can potentially use the new Metal Performance Shaders backend for GPU training
# acceleration. More information is available at https://developer.apple.com/metal/
# pytorch/ and https://pytorch.org/get-started/locally/. Throughout the book, you can use the following command to define the PyTorch device
#
# ```
# device="mps" if torch.backends.mps.is_available() else "cpu"
# ```
#
# If the value of the PyTorch device is mps, it means you can use your Mac for GPU training acceleration.

# %% [markdown]
# ## 2.2.	Use Google Colab for GPU training and inference

# %% [markdown]
# You can train and use PyTorch models in this book in Google Colab for free. To get started, log into your Google account and go to https://colab.research.google.com/. Start a new notebook in Google Colab, click on the "Runtime" menu, and select "Change runtime type" from the drop-down list, as shown in figure Appendix 3.

# %% [markdown]
# ![selectRunTime.png](attachment:selectRunTime.png)
#
# Figure Appendix 3: Changing the runtime type in a Google Colab notebook.

# %% [markdown]
# After selecting "Change runtime type" from the drop-down list, a new window will pop up, as shown in figure Appendix 4.

# %% [markdown]
# ![selectt4GPU.png](attachment:selectt4GPU.png)
# Figure Appendix 4: Selecting the T4 GPU as the hardware accelerator in Google Colab.

# %% [markdown]
# In the newly opened window, select “Python 3” as the runtime type and “T4 GPU” as the hardware accelerator. The T4 GPU (Tesla T4) is a powerful and flexible GPU optimized for machine learning training and inference. If you have a Google account, you can access a T4 GPU for free in Google Colab to train and run models in this book. Finally, click “Save” to apply the settings to your notebook.
# In Google Colab, there's no need to set up a virtual environment since most required libraries come preinstalled. If you encounter an error indicating a missing library, simply install it using pip install, and you'll be ready to proceed.
#
# All Python programs from each chapter of the book have been replicated in Google Colab for your convenience. Direct links to the Colab notebooks are provided in both the book and the individual Jupyter notebooks available in the book’s GitHub repository. For instance, you can access the notebook for chapter 2 here:
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1_mKkGGIXbE6efzAmRqpw8MzfYJFtkcFA?usp=sharing)
#
#
# To get started in any Colab notebook, simply clone the book’s GitHub repository using the commands below. This approach eliminates the need to manually upload files or modules. Everything is set up for you automatically:

# %%
# !git clone https://github.com/markhliu/txt2img
import sys
sys.path.append("/content/txt2img")

# %% [markdown]
# Access all Python programs in chapter 3
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1N_IkioLnMttphjXEEjRFLxq6BqKi6pV5?usp=sharing)

# %% [markdown]
# Chapter 4:
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1DLP7agKGHsiK8GZ5VtCgruH0f7Kt5jS1?usp=sharing)

# %% [markdown]
# Chapter 5:
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1htPAwH54cSX-PzadY3VX8ccvpC07-5-W?usp=sharing)

# %% [markdown]
# Chapter 6:
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/188wu7JJexIRjhmJAXPJGQbBoFafLHXRc?usp=sharing)

# %% [markdown]
# Chapter 7:
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/189bX_biF4fEBNuwFUf1NPR8d8kGVwNU1?usp=sharing)

# %% [markdown]
# Chapter 8:
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1m2eP7ajcwXQwJp1CE2O3y7KbvE_6BMD7?usp=sharing)

# %% [markdown]
# Chapter 9:
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1hjsK1MvUvrwlShtybD6vqZ_YQ-ElekrF?usp=sharing)

# %% [markdown]
# Chapter 10:
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/18lCSmwzqQ3r1pqPXocX2H8p-QmpkzJAv?usp=sharing)

# %% [markdown]
# Chapter 11:
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1zB2Ifg1RJeHOZvLQjFtbQCZqLURy8Gvd?usp=sharing)

# %% [markdown]
# Chapter 12: Because the model in this chapter is quite large and memory-intensive, I used two separate Colab notebooks. This allows you to run everything efficiently without requiring a paid GPU plan.
#
# Part 1:
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1uhA9Q66FX1mhXzUd3DBtaqI1CEKrsaWd?usp=sharing)
#
#
# Part 2:
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1zbmI8jN781l-czwlD-cTYvCyVJZXIvYq?usp=sharing)

# %% [markdown]
# Chapter 13:
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/15p4RIPTgM-7bUGc8ITYQd0tsHcavmTpH?usp=sharing)
